# %%
a = 5
b = a
print(id(a))
print(id(b))
print(a is b)
a = 6
print(id(a))
print(id(b))
print(a)
print(b)
print(a is b)
# Out:
# 2398822820272
# 2398822820272
# True
# 2398822820304
# 2398822820272
# 6
# 5
# False

# %%
a = [5,6]
b = a
print(id(a))
print(id(b))
print(a is b)
a[0] = 6
print(id(a))
print(id(b))
print(a)
print(b)
print(a is b)
# Out:
# 2398907776640
# 2398907776640
# True
# 2398907776640
# 2398907776640
# [6, 6]
# [6, 6]
# True

# %%
a = [5,6]
b = a
print(id(a))
print(id(b))
print(a is b)
a = [6,6]
print(id(a))
print(id(b))
print(a)
print(b)
print(a is b)
# Out:
# 2398907775168
# 2398907775168
# True
# 2398907776640
# 2398907775168
# [6, 6]
# [5, 6]
# False
